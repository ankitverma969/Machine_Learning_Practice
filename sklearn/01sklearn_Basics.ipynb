# %% [markdown]
# Scikit-learn (usually imported as sklearn) is one of the most popular Python libraries used for:
#
# Machine Learning
#
# Data preprocessing
#
# Model training
#
# Model evaluation
#
# Simple AI tasks
#
# It is designed to be super beginner-friendly, allowing you to build ML models in just a few lines of code.

# %% [markdown]
# 🧠 Why is sklearn important?
#
# Think of sklearn as a toolbox for machine learning.
# When you want to:
#
# classify emails as spam/not spam
#
# predict house prices
#
# cluster customers
#
# reduce dimensionality
#
# split training & test data
#
# …sklearn gives you ready-made tools so you don’t have to build everything from scratch.

# %% [markdown]
# 👍 What sklearn provides
# ✔ Models
#
# Linear Regression
#
# Logistic Regression
#
# Decision Trees
#
# Random Forest
#
# KNN
#
# SVM
#
# Neural networks (MLPClassifier)
#
# ✔ Data preprocessing
#
# Scaling
#
# Normalizing
#
# Encoding categorical data
#
# ✔ Utilities
#
# Train/test splitting
#
# Accuracy scoring
#
# Metrics
#
# Sklearn is not for deep learning (that’s PyTorch / TensorFlow), but it’s excellent for classic ML.
