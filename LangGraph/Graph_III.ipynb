# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitverma969/Machine_Learning_Practice/blob/master/LangGraph/Graph_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import TypedDict
from langgraph.graph import StateGraph

# %%
# Schema
class AgentState(TypedDict):
  name : str
  age : str
  final : str

# %%
# process the values and update the state
def first_node(state : AgentState) -> AgentState:
  state['final'] = f"Hi {state['name']}"
  return state

def second_node(state: AgentState) -> AgentState:
  state['final'] = state['final'] + f" You are {state['age']} years old !!"
  return state

# %%
graph = StateGraph(AgentState)

graph.add_node("1st_Node", first_node)
graph.add_node("2nd_Node", second_node)


graph.set_entry_point("1st_Node")

graph.add_edge("1st_Node", "2nd_Node")

graph.set_finish_point("2nd_Node")

app = graph.compile()

# %%
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))

# %%
app.invoke({
    "name" : "Ankit",
    "age" : "22"
})
# Out:
# {'name': 'Ankit', 'age': '22', 'final': 'Hi Ankit You are 22 years old !!'}

# %%
 ans = app.invoke({
    "name" : "Ankit",
    "age" : "22"
})

# %%
ans
# Out:
# {'name': 'Ankit', 'age': '22', 'final': 'Hi Ankit You are 22 years old !!'}

# %%
ans['final']
# Out:
# 'Hi Ankit You are 22 years old !!'
