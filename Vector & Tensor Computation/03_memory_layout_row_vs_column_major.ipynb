# %% [markdown]
# Memory Layout: Row-Major vs Column-Major (DSA for AI & ML)

# %%
import numpy as np

A = np.array([[1,2,3],
              [4,5,6]])

print(A.flatten(order='C'))

# %%
import numpy as np

A = np.array([[1,2,3],
              [4,5,6]])

print(A.flatten(order='F'))
