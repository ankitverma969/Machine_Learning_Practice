# %% [markdown]
# Tensor Shapes & Broadcasting (DSA for AI & ML)
#
# What Is a Tensor? (Clear Mental Model)
#
# | Name   | Dimension | Example Shape |
# | ------ | --------- | ------------- |
# | Scalar | 0D        | `()`          |
# | Vector | 1D        | `(5,)`        |
# | Matrix | 2D        | `(3, 4)`      |
# | Tensor | ND        | `(2, 3, 4)`   |

# %% [markdown]
# Scalar + Vector

# %%
import numpy as np

a = np.array([1, 2, 3])
b = 10

print(a + b)

# Computer pretends:

# b → [10, 10, 10]
# Out:
# [11 12 13]

# %%
M = np.array([[1,2,3],
              [4,5,6]])

v = np.array([10, 20, 30])

print(M + v)
# Out:
# [[11 22 33]
#  [14 25 36]]
