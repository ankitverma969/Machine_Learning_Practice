# %% [markdown]
# What is an NLP Pipeline?
#
# An NLP pipeline is a step-by-step process used to convert raw text (human language) into something a machine can understand and use to make decisions.
#
# Think of it like making tea ☕
# You don’t directly drink tea leaves—you follow steps.
#
# Step 1: Data Acquisition
# What it means
#
# Collecting text data.
#
# Examples
#
# Tweets
#
# Reviews from Amazon
#
# News articles
#
# Chat messages
#
# Emails
#
# Example
#
# Suppose we want to build a sentiment analysis system.
#
# 📥 Data:
#
# "I love this phone 😍"
# "This phone is very bad!!!"
#
# Step 2: Text Preparation (Very Important)
#
# Raw text is dirty. Machines hate dirty data 😄
# So we clean and prepare it.
#
# 2.1 Text Cleanup
# What we remove
#
# Emojis 😍
#
# Special characters !!! @@##
#
# Extra spaces
#
# Example
#
# Before:
#
# "I love this phone 😍!!!"
#
#
# After:
#
# "I love this phone"
#
# 2.2 Basic Preprocessing
#
# This makes text consistent.
#
# Common steps:
#
# Convert to lowercase
#
# Remove punctuation
#
# Tokenization (splitting words)
#
# Example
#
# Sentence:
#
# "I Love This Phone!"
#
#
# After preprocessing:
#
# ["i", "love", "this", "phone"]
#
# 2.3 Advanced Preprocessing
#
# Here we try to understand grammar & meaning.
#
# Examples:
#
# Stemming → loved → love
#
# Lemmatization → running → run
#
# POS Tagging (Part of Speech)
#
# POS Tagging Example
# "I love this phone"
#
# Word	POS
# I	Pronoun
# love	Verb
# this	Determiner
# phone	Noun
#
# This helps models understand how words are used, not just words.
#
# Step 3: Feature Engineering
# Big Question:
#
# ❓ How do we convert text → numbers?
#
# Because ML models understand only numbers.
#
# Common Techniques
#
# Bag of Words
#
# TF-IDF
#
# Word Embeddings (Word2Vec, GloVe)
#
# Example (Bag of Words)
#
# Sentences:
#
# "I love phone"
# "I hate phone"
#
#
# Vocabulary:
#
# ["i", "love", "hate", "phone"]
#
#
# Vector form:
#
# "I love phone" → [1,1,0,1]
# "I hate phone" → [1,0,1,1]
#
#
# Now the model can work 🎯
#
# Step 4: Modelling
# 4.1 Model Building
#
# We train a model using the numerical features.
#
# Examples of models
#
# Naive Bayes
#
# Logistic Regression
#
# SVM
#
# Deep Learning (LSTM, Transformers)
#
# Example:
#
# Input: "I love this phone"
# Output: Positive
#
# 4.2 Evaluation
#
# We check how good the model is.
#
# Metrics:
#
# Accuracy
#
# Precision
#
# Recall
#
# F1-score
#
# Example:
#
# Accuracy = 92%
#
#
# Means: Model is doing well 👍
#
# Step 5: Deployment
#
# Now we use the model in real life.
#
# Example
#
# A website that shows positive/negative reviews
#
# A chatbot replying to users
#
# Spam email detection
#
# Monitoring
#
# Check:
#
# Is model making mistakes?
#
# Is data changing?
#
# Model Update
#
# If performance drops:
#
# Retrain with new data
#
# Improve preprocessing
#
# Change model
#
# Points to Remember (Very Important)
#
# ✔ NLP pipeline is not fixed
# ✔ Steps can change based on problem
# ✔ Deep learning pipelines may skip feature engineering
# ✔ Pipeline is non-linear (you may go back and fix earlier steps)
#
# One Complete Simple Example
# Problem: Sentiment Analysis
#
# 1️⃣ Collect reviews
# 2️⃣ Clean text
# 3️⃣ Convert to numbers
# 4️⃣ Train model
# 5️⃣ Predict sentiment
# 6️⃣ Deploy on app
