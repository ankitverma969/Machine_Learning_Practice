# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitverma969/Machine_Learning_Practice/blob/master/LangGraph/Agent_II_WithShortMemory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-google-genai

# %%
from typing import TypedDict, List, Union
from langchain_core.messages import HumanMessage, AIMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
class AgentState(TypedDict):
    message : List[Union[HumanMessage, AIMessage]]

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %%
def process(state: AgentState) -> AgentState:
  response = llm.invoke(state['message'])

  state['message'].append(AIMessage(content=response.content))
  print(f"\nAI Response", {response.content})
  print(f"\nCurrent Chat: ", state['message'])
  return state

# %%
graph = StateGraph(AgentState)

graph.add_node("process", process)
graph.add_edge(START, "process")
graph.add_edge("process", END)

agent = graph.compile()

# %%
conversation_history = []
user_input = input("Enter: ")

while user_input != "exit":
  conversation_history.append(HumanMessage(content=user_input))

  result = agent.invoke({"message" : conversation_history})

  # print(result['message'])

  conversation_history = result['message']

  user_input = input("Enter: ")
# Out:
# Enter: Tell me my name
#
# AI Response {'As a large language model, I do not have access to personal information and cannot determine your name. You have not provided me with that information.'}
#
# Current Chat:  [HumanMessage(content='Tell me my name', additional_kwargs={}, response_metadata={}), AIMessage(content='As a large language model, I do not have access to personal information and cannot determine your name. You have not provided me with that information.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]
# Enter: exit
